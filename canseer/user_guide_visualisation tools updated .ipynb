# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# # Table of Contents
# * [Data wrangling](#chapter1)
#     * [Dataframes](#section_1_1)
#     * [Data filters](#section_1_2)
#     * [Help functions](#section_1_3)
# * [Visualisation tools](#chapter2)
#     * [Stack plot](#section_2_1)
#     * [Proportion of breaches](#section_2_2)
#     * [Map of England](#section_2_3)

# %%
 # Data wrangling <a class="anchor" id="chapter1"></a>

# %%
# Dataframes <a class="anchor" id="section_1_1"></a>

# %% [markdown]
#  get_provider_data produces a dataframe on cancer diagnosis referalls and treatment referalls by providers e.g. NHS trusts.

# %%
from canseer.data_wrangling import get_provider_data

# %%
df_provider = get_provider_data()

# %%
df_provider.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 103185 entries, 2022-04-01 to 2023-03-01
# Data columns (total 8 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   standard            103185 non-null  category
#  1   org_code            103185 non-null  category
#  2   stage_or_route      103185 non-null  category
#  3   treatment_modality  103185 non-null  category
#  4   cancer_type         103185 non-null  category
#  5   total               103185 non-null  int32
#  6   within_standard     103185 non-null  int32
#  7   breaches            103185 non-null  int32
# dtypes: category(5), int32(3)
# memory usage: 2.6 MB

# %%
df_provider.tail()
# Out:
#                    standard org_code           stage_or_route  \
# month
# 2023-03-01  62-day Combined      RWD  urgent_suspected_cancer
# 2023-03-01  62-day Combined      RWP  urgent_suspected_cancer
# 2023-03-01  62-day Combined      RXN  urgent_suspected_cancer
# 2023-03-01  62-day Combined      RXW  urgent_suspected_cancer
# 2023-03-01  62-day Combined      RY2  urgent_suspected_cancer
#
#            treatment_modality  cancer_type  total  within_standard  breaches
# month
# 2023-03-01            surgery  All_Cancers     83               53        30
# 2023-03-01            surgery  All_Cancers    116               70        46
# 2023-03-01            surgery  All_Cancers     73               27        46
# 2023-03-01            surgery  All_Cancers    103               65        37
# 2023-03-01            surgery  All_Cancers     12                8         4

# %% [markdown]
# get_national_28_day_standard, get_national_31_day_standard and get_national_61_day_standard
# create a dataframe from data on cancer diagnosis and treatment referalls on a national level.
# These could be appended to the provider dataframe.

# %%
from canseer.data_wrangling import get_national_28_day_standard
from canseer.data_wrangling import get_national_31_day_standard
from canseer.data_wrangling import get_national_62_day_standard

# %%
df_nat_fds = get_national_28_day_standard()

# %%
df_nat_fds.head()
# Out:
#              total  within_standard  breaches org_code    standard  \
# month
# 2021-04-01  211835           154535     57300      NAT  28-day FDS
# 2021-05-01  210267           156199     54068      NAT  28-day FDS
# 2021-06-01  233181           170194     62987      NAT  28-day FDS
# 2021-07-01  222389           164461     57928      NAT  28-day FDS
# 2021-08-01  208788           151470     57318      NAT  28-day FDS
#
#                   cancer_type  treatment_modality  \
# month
# 2021-04-01  all_national_data  not_applicable_FDS
# 2021-05-01  all_national_data  not_applicable_FDS
# 2021-06-01  all_national_data  not_applicable_FDS
# 2021-07-01  all_national_data  not_applicable_FDS
# 2021-08-01  all_national_data  not_applicable_FDS
#
#                           stage_or_route
# month
# 2021-04-01  not_applicable_national_data
# 2021-05-01  not_applicable_national_data
# 2021-06-01  not_applicable_national_data
# 2021-07-01  not_applicable_national_data
# 2021-08-01  not_applicable_national_data

# %%
df_provider_nat = df_provider._append(get_national_28_day_standard())

# %%
df_provider_nat.tail()
# Out:
#               standard org_code                stage_or_route  \
# month
# 2023-06-01  28-day FDS      NAT  not_applicable_national_data
# 2023-07-01  28-day FDS      NAT  not_applicable_national_data
# 2023-08-01  28-day FDS      NAT  not_applicable_national_data
# 2023-09-01  28-day FDS      NAT  not_applicable_national_data
# 2023-10-01  28-day FDS      NAT  not_applicable_national_data
#
#             treatment_modality        cancer_type   total  within_standard  \
# month
# 2023-06-01  not_applicable_FDS  all_national_data  259629           190807
# 2023-07-01  not_applicable_FDS  all_national_data  252133           186879
# 2023-08-01  not_applicable_FDS  all_national_data  264533           189443
# 2023-09-01  not_applicable_FDS  all_national_data  258858           180534
# 2023-10-01  not_applicable_FDS  all_national_data  271402           192880
#
#             breaches
# month
# 2023-06-01     68822
# 2023-07-01     65254
# 2023-08-01     75090
# 2023-09-01     78324
# 2023-10-01     78522

# %%
df_nat_dtt = get_national_31_day_standard()

# %%
df_nat_dtt.head()
# Out:
#             total  within_standard  breaches org_code         standard  \
# month
# 2022-04-01  45336            41965      3371      NAT  31-day Combined
# 2022-05-01  51800            47598      4202      NAT  31-day Combined
# 2022-06-01  48362            44337      4025      NAT  31-day Combined
# 2022-07-01  48195            44649      3546      NAT  31-day Combined
# 2022-08-01  50877            46668      4209      NAT  31-day Combined
#
#                   cancer_type            treatment_modality  \
# month
# 2022-04-01  all_national_data  not_applicable_national_data
# 2022-05-01  all_national_data  not_applicable_national_data
# 2022-06-01  all_national_data  not_applicable_national_data
# 2022-07-01  all_national_data  not_applicable_national_data
# 2022-08-01  all_national_data  not_applicable_national_data
#
#                           stage_or_route
# month
# 2022-04-01  not_applicable_national_data
# 2022-05-01  not_applicable_national_data
# 2022-06-01  not_applicable_national_data
# 2022-07-01  not_applicable_national_data
# 2022-08-01  not_applicable_national_data

# %%
df_nat_rtt = get_national_62_day_standard()

# %%
df_nat_rtt.head()
# Out:
#             total  within_standard  breaches org_code         standard  \
# month
# 2022-04-01  19489            13456      6033      NAT  62-day Combined
# 2022-05-01  22696            14859      7837      NAT  62-day Combined
# 2022-06-01  21136            13539      7597      NAT  62-day Combined
# 2022-07-01  21289            13980      7309      NAT  62-day Combined
# 2022-08-01  22610            14760      7850      NAT  62-day Combined
#
#                   cancer_type            treatment_modality  \
# month
# 2022-04-01  all_national_data  not_applicable_national_data
# 2022-05-01  all_national_data  not_applicable_national_data
# 2022-06-01  all_national_data  not_applicable_national_data
# 2022-07-01  all_national_data  not_applicable_national_data
# 2022-08-01  all_national_data  not_applicable_national_data
#
#                           stage_or_route
# month
# 2022-04-01  not_applicable_national_data
# 2022-05-01  not_applicable_national_data
# 2022-06-01  not_applicable_national_data
# 2022-07-01  not_applicable_national_data
# 2022-08-01  not_applicable_national_data

# %% [markdown]
# # Data filters <a class="anchor" id="section_1_2"></a>

# %% [markdown]
# To select particular patient groups within any dataframe our filter functions can be used.
# The following filter functions are available select_months, select_org, select_cancer,
# select_standard, select_treatment_modality, select_stage_or_route, filter_data.

# %%
from canseer.data_wrangling import select_months, select_org, select_cancer, select_standard
from canseer.data_wrangling import select_treatment_modality, select_stage_or_route, filter_data

# %%
df_provider.head()
# Out:
#               standard org_code             stage_or_route  \
# month
# 2022-04-01  28-day FDS      R1K  breast_symptom_non_cancer
# 2022-04-01  28-day FDS      R0A  breast_symptom_non_cancer
# 2022-04-01  28-day FDS      R0D  breast_symptom_non_cancer
# 2022-04-01  28-day FDS      R1F  breast_symptom_non_cancer
# 2022-04-01  28-day FDS      RAS  breast_symptom_non_cancer
#
#             treatment_modality            cancer_type  total  within_standard  \
# month
# 2022-04-01  not_applicable_FDS  Unsuspected_breast_ca    262              255
# 2022-04-01  not_applicable_FDS  Unsuspected_breast_ca    382              144
# 2022-04-01  not_applicable_FDS  Unsuspected_breast_ca      3                2
# 2022-04-01  not_applicable_FDS  Unsuspected_breast_ca     66               63
# 2022-04-01  not_applicable_FDS  Unsuspected_breast_ca     81               78
#
#             breaches
# month
# 2022-04-01         7
# 2022-04-01       238
# 2022-04-01         1
# 2022-04-01         3
# 2022-04-01         3

# %% [markdown]
# For example select_org is used on the provider dataset to filter by organisation.

# %%
df_provider_r1k_r0A = select_org(df_provider, ['R1K', 'R0A'])

# %%
df_provider_r1k_r0A.head()
# Out:
#               standard org_code             stage_or_route  \
# month
# 2022-04-01  28-day FDS      R1K  breast_symptom_non_cancer
# 2022-04-01  28-day FDS      R0A  breast_symptom_non_cancer
# 2022-04-01  28-day FDS      R0A                  screening
# 2022-04-01  28-day FDS      R1K                  screening
# 2022-04-01  28-day FDS      R1K                  screening
#
#             treatment_modality                 cancer_type  total  \
# month
# 2022-04-01  not_applicable_FDS       Unsuspected_breast_ca    262
# 2022-04-01  not_applicable_FDS       Unsuspected_breast_ca    382
# 2022-04-01  not_applicable_FDS                     Invalid    143
# 2022-04-01  not_applicable_FDS         Suspected_breast_ca      4
# 2022-04-01  not_applicable_FDS  Suspected_gynecological_ca     35
#
#             within_standard  breaches
# month
# 2022-04-01              255         7
# 2022-04-01              144       238
# 2022-04-01               67        76
# 2022-04-01                2         2
# 2022-04-01               12        23

# %% [markdown]
# The filter functions can also be used on the national dataframe

# %%
df_nat_fds.head()
# Out:
#              total  within_standard  breaches org_code    standard  \
# month
# 2021-04-01  211835           154535     57300      NAT  28-day FDS
# 2021-05-01  210267           156199     54068      NAT  28-day FDS
# 2021-06-01  233181           170194     62987      NAT  28-day FDS
# 2021-07-01  222389           164461     57928      NAT  28-day FDS
# 2021-08-01  208788           151470     57318      NAT  28-day FDS
#
#                   cancer_type  treatment_modality  \
# month
# 2021-04-01  all_national_data  not_applicable_FDS
# 2021-05-01  all_national_data  not_applicable_FDS
# 2021-06-01  all_national_data  not_applicable_FDS
# 2021-07-01  all_national_data  not_applicable_FDS
# 2021-08-01  all_national_data  not_applicable_FDS
#
#                           stage_or_route
# month
# 2021-04-01  not_applicable_national_data
# 2021-05-01  not_applicable_national_data
# 2021-06-01  not_applicable_national_data
# 2021-07-01  not_applicable_national_data
# 2021-08-01  not_applicable_national_data

# %%
dfs_nat_fds_april_may = select_months(df_nat_fds, '04/2021','05/2021')

# %%
dfs_nat_fds_april_may.head()
# Out:
#              total  within_standard  breaches org_code    standard  \
# month
# 2021-04-01  211835           154535     57300      NAT  28-day FDS
# 2021-05-01  210267           156199     54068      NAT  28-day FDS
#
#                   cancer_type  treatment_modality  \
# month
# 2021-04-01  all_national_data  not_applicable_FDS
# 2021-05-01  all_national_data  not_applicable_FDS
#
#                           stage_or_route
# month
# 2021-04-01  not_applicable_national_data
# 2021-05-01  not_applicable_national_data

# %% [markdown]
# filter_data() can be used to select patient groups based on multiple filters in the dataframes.

# %%
filters = { 'stage_or_route': ['urgent_suspected_cancer', 'screening'],
           'standard': 'FDS',
          'org': ['RWP', 'RXQ','R0A'],
          }
df_provider_filter = filter_data(df_provider, filters)
df_provider_filter.head(10)
# Out:
#               standard org_code           stage_or_route  treatment_modality  \
# month
# 2022-04-01  28-day FDS      R0A                screening  not_applicable_FDS
# 2022-04-01  28-day FDS      RXQ                screening  not_applicable_FDS
# 2022-04-01  28-day FDS      RWP                screening  not_applicable_FDS
# 2022-04-01  28-day FDS      RWP                screening  not_applicable_FDS
# 2022-04-01  28-day FDS      RXQ                screening  not_applicable_FDS
# 2022-04-01  28-day FDS      R0A  urgent_suspected_cancer  not_applicable_FDS
# 2022-04-01  28-day FDS      RXQ  urgent_suspected_cancer  not_applicable_FDS
# 2022-04-01  28-day FDS      RWP  urgent_suspected_cancer  not_applicable_FDS
# 2022-04-01  28-day FDS      R0A  urgent_suspected_cancer  not_applicable_FDS
# 2022-04-01  28-day FDS      RXQ  urgent_suspected_cancer  not_applicable_FDS
#
#                        cancer_type  total  within_standard  breaches
# month
# 2022-04-01                 Invalid    143               67        76
# 2022-04-01     Suspected_breast_ca     29               23         6
# 2022-04-01     Suspected_breast_ca     18               17         1
# 2022-04-01   Suspected_lower_GI_ca      1                0         1
# 2022-04-01   Suspected_lower_GI_ca      2                2         0
# 2022-04-01     Suspected_breast_ca   1135              361       774
# 2022-04-01  Suspected_brain_CNS_ca      2                0         2
# 2022-04-01     Suspected_breast_ca    225              208        17
# 2022-04-01   Suspected_children_ca      3                1         2
# 2022-04-01     Suspected_breast_ca    380              369        11

# %%
# Help functions <a class="anchor" id="section_1_3"></a>

# %% [markdown]
# help_with provides more information on the cancer referrals data.

# %%
from data_wrangling import help_with

# %%
help_with()
# Out:
# Please select which aspect of the data you need help with:
# 1.) NHS Cancer standards
# 2.) Types of cancer
# 3.) NHS Organisation Codes
# 4.) Stage/Route
# 5.) Treatment modality
# 6.) Breaches
# 7.) Within Standard
#
#
# Select the number of a topic from above:
#
# 1
# There are three standards present in this dataset:
#  1. The 28-day Faster Diagnosis Standard (FDS).
# The standard: People should have cancer ruled out or receive a diagnosis within 28 days
# NHS target: 75% of people should meet this standard
#
#  2. 31-day decision to treat to treatment standard (DTT).
# The standard: Treatment should begin within a month (31 days)of deciding to treat their cancer.
# NHS target: 96% of people should meet this standard
#
#  3.62-day referral to treatment standard
# The standard: Treatment should begin withintwo months (62 days) of an urgent referral.
# NHS target: 85% of people should meet this standard
#
#
#  Further info at:  https://news.cancerresearchuk.org/2023/08/17/breaking-down-nhs-englands-changes-in-standards-for-cancer-care/

# %% [markdown]
# name_org_code can be used to provide the org_code of a particular NHS Trust.

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from canseer.data_wrangling import name_org_code
#
# ModuleNotFoundError: No module named 'canseer'

# %%
# Out:
#               standard org_code             stage_or_route  \
# month
# 2022-04-01  28-day FDS      R1K  breast_symptom_non_cancer
# 2022-04-01  28-day FDS      R0A  breast_symptom_non_cancer
# 2022-04-01  28-day FDS      R0D  breast_symptom_non_cancer
# 2022-04-01  28-day FDS      R1F  breast_symptom_non_cancer
# 2022-04-01  28-day FDS      RAS  breast_symptom_non_cancer
#
#             treatment_modality            cancer_type  total  within_standard  \
# month
# 2022-04-01  not_applicable_FDS  Unsuspected_breast_ca    262              255
# 2022-04-01  not_applicable_FDS  Unsuspected_breast_ca    382              144
# 2022-04-01  not_applicable_FDS  Unsuspected_breast_ca      3                2
# 2022-04-01  not_applicable_FDS  Unsuspected_breast_ca     66               63
# 2022-04-01  not_applicable_FDS  Unsuspected_breast_ca     81               78
#
#             breaches  proportion_breaches  moving_average
# month
# 2022-04-01         7             0.026718             NaN
# 2022-04-01       238             0.623037             NaN
# 2022-04-01         1             0.333333        0.327696
# 2022-04-01         3             0.045455        0.333942
# 2022-04-01         3             0.037037        0.138608

# %%
from canseer.cancer_plotting import prop_breaches_graph

# %%
filters = {'standard':'RTT', 
           'org': 'RMC', 
           'treatment': 'surgery', 
           'stage_or_route':'urgent_suspected_cancer'}
labels = ['RMC referrals for surgery on the urgent suspected cancer pathway',
         'National Referall to Treat Standard']
prop_breaches_graph(df_provider, filters, labels)
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: title={'center': 'Proportion of breaches over time'}, xlabel='Month', ylabel='Proportion of breaches'>)
